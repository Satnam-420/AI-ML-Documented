# %% [markdown]
# # This notebook analyses 150 samples, with 50 samples for each of the three species: Iris setosa, Iris versicolor, and Iris virginica

# %% [markdown]
# ## This notebook documents my first EDA project on the Iris dataset, where I explored species differences using Pandas and Matplotlib.

# %% [markdown]
# ## Task 1 : Exploring Dataset and inspecting it. (1 May ,2025)

# %%
import pandas as pd
iris_data = pd.read_csv("../Datasets/Iris.csv")  
print("First five rows of the dataset")
display(iris_data.head())
print("\nDataset Information")
print(iris_data.info())
print("\nSummary Statistics")
print(iris_data.describe())
print ("Day 1 Results")
# Out:
# First five rows of the dataset
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# ...

# %%
# Observed 150 rows and 5 columns.

# %% [markdown]
# # Day 1: Exploring the Iris Dataset with Visualizations (May 1 , 2025)

# %% [markdown]
# ## Started visualizing the Iris dataset to find species patterns.

# %% [markdown]
# ## Creating a scatter plot for the Iris Dataset.

# %%
import matplotlib.pyplot as plt
setosa = iris_data[iris_data['Species'] == 'Iris-setosa']
versicolor = iris_data[iris_data['Species'] == 'Iris-versicolor']
virginica = iris_data[iris_data['Species'] == 'Iris-virginica']
plt.scatter(setosa['SepalLengthCm'], setosa['PetalLengthCm'], color='blue', label='Setosa')
plt.scatter(versicolor['SepalLengthCm'], versicolor['PetalLengthCm'], color='orange', label='Versicolor')
plt.scatter(virginica['SepalLengthCm'], virginica['PetalLengthCm'], color='green', label='Virginica')
plt.title('Flower Measurements by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()

# %% [markdown]
# ## Observations : Setosa lies lower on the y-axis , hence it's distinct from the other two. Versicolor and Virginica overlap each other more.

# %% [markdown]
# # Creating a Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(iris_data['PetalLengthCm'], bins=20, color='purple', edgecolor='black')
plt.xlabel ("Petal length (in cm)")
plt.ylabel ("Frequency")
plt.title("Petal length distribution")
plt.show()

# %% [markdown]
# ## Observed two peaks : One near 1.5 range likely Setosa and the other around 4-5 cm likely versicolor or Virginica.

# %% [markdown]
# ## Concluded Day 1 i.e May 1, 2025 , Learnt to create a scatter plot and a histogram using matplotlib , recorded the observations. Ready for more tomorrow.

# %% [markdown]
# # Day 2 : Missing values check, Group stats, Box plot. (May 2, 2025)

# %% [markdown]
# ### Adding more EDA steps and summarizing findings.

# %% [markdown]
# ## Check for Missing Values

# %%
import pandas as pd
iris_data = pd.read_csv("../Datasets/Iris.csv")
print("Missing values in the data:")
print(iris_data.isnull().sum())
# Out:
# Missing values in the data:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Observations: No empty value in the csv, hence the dataset is clean.

# %% [markdown]
# # Group Statistics

# %%
import pandas as pd
iris_data = pd.read_csv("../Datasets/Iris.csv")
print("Average feature values by species.")
print(iris_data.groupby("Species").mean())
# Out:
# Average feature values by species.
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %% [markdown]
# ## Observations from Group Statistics
# ### Setosa’s average petal length is ~1.5 cm, Versicolor ~4.3 cm, and Virginica ~5.5 cm, matching the scatter plot and histogram from Day 1.

# %% [markdown]
# # Box Plot (Petal Length by Species)

# %%
import matplotlib.pyplot as plt
plt.boxplot([iris_data[iris_data['Species'] == 'Iris-setosa']['PetalLengthCm'],
             iris_data[iris_data['Species'] == 'Iris-versicolor']['PetalLengthCm'],
             iris_data[iris_data['Species'] == 'Iris-virginica']['PetalLengthCm']],
            tick_labels=['Setosa', 'Versicolor', 'Virginica'])
plt.title('Petal Length Spread by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# %% [markdown]
# ## Observations from Box Plot
# ### Setosa’s petal length is tightly grouped (1–2 cm) with no outliers. Versicolor and Virginica have wider ranges, with medians around 4.3 cm and 5.5 cm.

# %% [markdown]
# # Create a Scatter Plot (Sepal Length vs. Sepal Width)

# %%
import matplotlib.pyplot as plt
plt.scatter(iris_data[iris_data['Species'] == 'Iris-setosa']['SepalLengthCm'],
            iris_data[iris_data['Species'] == 'Iris-setosa']['SepalWidthCm'],
            color='blue', label='Setosa')
plt.scatter(iris_data[iris_data['Species'] == 'Iris-versicolor']['SepalLengthCm'],
            iris_data[iris_data['Species'] == 'Iris-versicolor']['SepalWidthCm'],
            color='orange', label='Versicolor')
plt.scatter(iris_data[iris_data['Species'] == 'Iris-virginica']['SepalLengthCm'],
            iris_data[iris_data['Species'] == 'Iris-virginica']['SepalWidthCm'],
            color='green', label='Virginica')
plt.title('Sepal Length vs. Sepal Width by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.show()

# %% [markdown]
# ##  Observations from Sepal Length vs. Sepal Width
# ### Sepal measurements show more overlap between species compared to petal measurements. Petal length is more useful for separating species.

# %% [markdown]
# # Summarizing Key Findings

# %%
print("Petal Length Statistics by Species:")
print(iris_data.groupby('Species')['PetalLengthCm'].describe())
# Out:
# Petal Length Statistics by Species:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %% [markdown]
# # Summary of Findings
# ### - Petal Length is the most distinguishing feature: Setosa (~1–2 cm), Versicolor (~4–4.5 cm), Virginica (~5–6 cm).
# ### - Sepal measurements (length and width) show more overlap, making them less useful for classification.
# ### - The dataset is clean with no missing values, ideal for future ML tasks.
# ### - Visuals (scatter plots, histograms, box plots) and stats helped confirm these patterns.

# %% [markdown]
# ## Conclusion
# ### This project taught me how to load, inspect, and visualize data to find patterns.
